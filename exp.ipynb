# %%
pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# absl-py                      2.2.0
# accelerate                   1.5.2
# aiohappyeyeballs             2.4.3
# aiohttp                      3.10.9
# aiosignal                    1.3.1
# ankh                         1.10.0
# anyio                        4.6.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        24.2.0
# babel                        2.16.0
# beautifulsoup4               4.12.3
# biopython                    1.84
# biotite                      0.41.2
# bleach                       6.1.0
# Brotli                       1.1.0
# certifi                      2024.8.30
# cffi                         1.17.1
# charset-normalizer           3.3.2
# clarabel                     0.9.0
# ...

# %%
import numpy as np
from pauc.pauc import plot_roc_with_ci

# %%
y_pred = np.random.randint(0, 2, 1000)
y_true = np.random.randint(0, 2, 1000)
probs = np.random.rand(1000)
y_pred.shape, y_true.shape, probs.shape
# Out:
# ((1000,), (1000,), (1000,))

# %%
plot_roc_with_ci(y_true, probs)
# Out:
# (1000, 2) (1000, 2) 2 binary
